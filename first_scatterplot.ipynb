# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
sns.set_style("darkgrid")

# %%
import matplotlib.pyplot as plt

# %%
sns.relplot(x = "total_bill", y = "tip", data = df)

# %%
# 2nd way of writing same thing
plt.figure(figsize = (9, 8))
sns.scatterplot(x = df['total_bill'], y = df['tip'])

# %%
# 3rd way of writing same thing
plt.figure(figsize = (9,8))
sns.scatterplot(x = 'total_bill', y = 'tip', data = df)

# %%
plt.figure(figsize = (9, 8))
sns.regplot(x = 'total_bill', y = 'tip', data = df)

# %% [markdown]
# ## In the above figure we can see that as the total_bill increases, tip also increases.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize = (9, 8))
sns.scatterplot(x = 'total_bill', y = 'tip', data = df, hue = 'sex')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, hue = 'sex')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, hue = 'sex', palette = 'Set1')

# %%
df['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, hue = 'sex', col = 'day')

# %%
# width = aspect * height
sns.lmplot(x = 'total_bill', y = 'tip', data = df, hue = 'sex', col = 'day', aspect = 0.6, size = 8)
# Out:
# C:\Users\Keshav Sharma\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, hue = 'sex', markers = ['o', 'x'])
